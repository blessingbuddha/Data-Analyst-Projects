# %%
import pandas as pd

# %%
data = pd.read_csv("./data set 5~alt_fuel_stations(Nov-3-2023).csv",low_memory=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78373 entries, 0 to 78372
# Data columns (total 74 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Fuel Type Code                           78373 non-null  object
#  1   Station Name                             78372 non-null  object
#  2   Street Address                           78332 non-null  object
#  3   Intersection Directions                  4860 non-null   object
#  4   City                                     78369 non-null  object
#  5   State                                    78359 non-null  object
#  6   ZIP                                      78367 non-null  object
#  7   Plus4                                    0 non-null      float64
#  8   Station Phone                            73330 non-null  object
#  9   Status Code                              78373 non-null  object
# ...

# %%
data.describe()
# Out:
#        Plus4  EV Level1 EVSE Num  EV Level2 EVSE Num  EV DC Fast Count  \
# count    0.0          727.000000        58794.000000       9152.000000
# mean     NaN            4.441541            2.366024          4.037478
# std      NaN            9.527202            3.134686          4.947789
# min      NaN            1.000000            1.000000          1.000000
# 25%      NaN            1.000000            2.000000          1.000000
# 50%      NaN            2.000000            2.000000          2.000000
# 75%      NaN            3.000000            2.000000          6.000000
# max      NaN          121.000000          338.000000         84.000000
#
#            Latitude             ID  Federal Agency ID  \
# count  78372.000000   78373.000000        1330.000000
# mean      37.831102  177138.141835          13.543609
# std        5.026929   74447.861329           6.132839
# min        0.000000      17.000000           2.000000
# ...

# %%
data.isna()
# Out:
#        Fuel Type Code  Station Name  Street Address  Intersection Directions  \
# 0               False         False           False                     True
# 1               False         False           False                     True
# 2               False         False           False                     True
# 3               False         False           False                     True
# 4               False         False           False                    False
# ...               ...           ...             ...                      ...
# 78368           False         False           False                     True
# 78369           False         False           False                     True
# 78370           False         False           False                     True
# 78371           False         False           False                     True
# 78372           False         False           False                     True
#
# ...

# %%
data.isna().value_counts()
# Out:
# Fuel Type Code  Station Name  Street Address  Intersection Directions  City   State  ZIP    Plus4  Station Phone  Status Code  Expected Date  Groups With Access Code  Access Days Time  Cards Accepted  BD Blends  NG Fill Type Code  NG PSI  EV Level1 EVSE Num  EV Level2 EVSE Num  EV DC Fast Count  EV Other Info  EV Network  EV Network Web  Geocode Status  Latitude  Longitude  Date Last Confirmed  ID     Updated At  Owner Type Code  Federal Agency ID  Federal Agency Name  Open Date  Hydrogen Status Link  NG Vehicle Class  LPG Primary  E85 Blender Pump  EV Connector Types  Country  Intersection Directions (French)  Access Days Time (French)  BD Blends (French)  Groups With Access Code (French)  Hydrogen Is Retail  Access Code  Access Detail Code  Federal Agency Code  Facility Type  CNG Dispenser Num  CNG On-Site Renewable Source  CNG Total Compression Capacity  CNG Storage Capacity  LNG On-Site Renewable Source  E85 Other Ethanol Blends  EV Pricing  EV Pricing (French)  LPG Nozzle Types 
# ...
